# %%
# Importing all the essential Python libraries

import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
sns.set_style('whitegrid')

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing Stock market data from the Internet
from pandas_datareader import data, wb

# %%
# Importing datetime for setting start and end date of the stock market dataset

from datetime import datetime

# %%
# Setting the Start and End date for Stock Market Analysis

end = datetime.now()
start = datetime(end.year-1,end.month,end.day)

# %%
# Importing Stock Prices
AAPL = data.DataReader('AAPL','yahoo',start,end)
MSFT = data.DataReader('MSFT','yahoo',start,end)
AMZN = data.DataReader('AMZN','yahoo',start,end)
GOOGL = data.DataReader('GOOGL','yahoo',start,end)

# %%
AAPL
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-02-18   79.937500   78.652496   78.839996   79.750000  152531200.0
# 2020-02-19   81.142502   80.000000   80.000000   80.904999   93984000.0
# 2020-02-20   81.162498   79.552498   80.657501   80.074997  100566000.0
# 2020-02-21   80.112503   77.625000   79.654999   78.262497  129554000.0
# 2020-02-24   76.044998   72.307503   74.315002   74.544998  222195200.0
# ...                ...         ...         ...         ...          ...
# 2021-02-12  135.529999  133.690002  134.350006  135.369995   60029300.0
# 2021-02-16  136.009995  132.789993  135.490005  133.190002   80206200.0
# 2021-02-17  132.220001  129.470001  131.250000  130.839996   97918500.0
# 2021-02-18  130.000000  127.410004  129.199997  129.710007   96648100.0
# 2021-02-19  130.710007  129.449997  130.240005  130.449997   34853626.0
#
#              Adj Close
# Date
# 2020-02-18   79.136566
# 2020-02-19   80.282684
# ...

# %%
# Some Basic info about the Apple Stock
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   121.359348  118.301946  119.946927  119.846442  1.236878e+08
# std     12.788996   12.595187   12.796616   12.676022  5.381194e+07
# min     88.300003   86.180000   87.834999   87.430000  4.669130e+07
# 25%    116.042503  112.800003  114.620003  114.959999  8.810510e+07
# 50%    123.870003  120.540001  122.540001  122.150002  1.105776e+08
# 75%    130.169998  126.940002  128.697495  128.699997  1.507120e+08
# max    145.089996  141.369995  143.600006  143.160004  3.743368e+08
#
#         Adj Close
# count  253.000000
# mean   119.457151
# std     12.796242
# min     86.844833
# 25%    114.396454
# 50%    121.860611
# 75%    128.290054
# max    142.704010

# %%
# Some Basic info about the Microsoft Stock
MSFT.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   227.085573  222.492806  224.769130  224.870553  3.004976e+07
# std     17.842974   18.255358   18.042964   18.081008  9.987593e+06
# min    195.580002  191.460007  192.889999  193.570007  1.055060e+07
# 25%    213.259995  208.320007  210.880005  210.580002  2.324930e+07
# 50%    222.089996  216.729996  218.589996  219.279999  2.762760e+07
# 75%    243.229996  238.600006  239.570007  240.970001  3.397970e+07
# max    263.190002  260.170013  261.660004  261.970001  7.898300e+07
#
#         Adj Close
# count  253.000000
# mean   223.746854
# std     18.570029
# min    191.713745
# 25%    209.422974
# 50%    218.079422
# 75%    240.414856
# max    261.366486

# %%
# Some Basic info about the Amazon Stock
AMZN.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count   253.000000   253.000000   253.000000   253.000000  2.530000e+02
# mean   3217.235129  3139.232765  3181.653088  3177.520308  4.198568e+06
# std     159.176285   159.557465   160.482555   157.799771  1.475802e+06
# min    2620.000000  2576.000000  2620.000000  2615.270020  1.451900e+06
# 25%    3142.100098  3073.000000  3107.000000  3102.969971  3.093900e+06
# 50%    3221.000000  3144.020020  3191.000000  3185.270020  3.916500e+06
# 75%    3320.000000  3241.199951  3282.419922  3283.959961  4.971900e+06
# max    3554.000000  3486.689941  3547.000000  3531.449951  8.892600e+06
#
#          Adj Close
# count   253.000000
# mean   3177.520308
# std     157.799771
# min    2615.270020
# 25%    3102.969971
# 50%    3185.270020
# 75%    3283.959961
# max    3531.449951

# %%
# Some Basic info about the Google Stock
GOOGL.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count   253.000000   253.000000   253.000000   253.000000  2.530000e+02
# mean   1853.739404  1813.944431  1832.789483  1834.368574  1.705272e+06
# std     316.367933   315.372130   316.334676   316.330977  7.091497e+05
# min    1398.000000  1351.650024  1360.339966  1362.540039  4.656000e+05
# 25%    1558.719971  1516.500000  1531.650024  1535.119995  1.257500e+06
# 50%    1770.380005  1738.569946  1760.000000  1758.569946  1.545500e+06
# 75%    2099.500000  2056.449951  2074.800049  2084.520020  1.953600e+06
# max    2455.510010  2421.120117  2449.000000  2448.909912  4.993900e+06
#
#          Adj Close
# count   253.000000
# mean   1834.368574
# std     316.330977
# min    1362.540039
# 25%    1535.119995
# 50%    1758.569946
# 75%    2084.520020
# max    2448.909912

# %%
# Plotting Adjusted Closing price for All Stock

AAPL['Adj Close'].plot(legend=True,figsize=(10,4),title='APPLE')

# %%
AMZN['Adj Close'].plot(legend=True,figsize=(10,4),title='AMAZON')

# %%
MSFT['Adj Close'].plot(legend=True,figsize=(10,4),title='MICROSOFT')

# %%
GOOGL['Adj Close'].plot(legend=True,figsize=(10,4),title='GOOGLE')

# %%
# Plotting the total volume of stock being traded each day

AAPL['Volume'].plot(legend=True,figsize=(10,4),title='APPLE')

# %%
AMZN['Volume'].plot(legend=True,figsize=(10,4),title='AMAZON')

# %%
MSFT['Volume'].plot(legend=True,figsize=(10,4),title='MICROSOFT')

# %%
GOOGL['Volume'].plot(legend=True,figsize=(10,4),title='GOOGLE')

# %%
# Calculating Moving average for 10, 20 and 50 days of the stock price

ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    
    AAPL[column_name] = pd.DataFrame.rolling(AAPL['Adj Close'],ma)
    AMZN[column_name] = pd.DataFrame.rolling(AMZN['Adj Close'],ma)
    MSFT[column_name] = pd.DataFrame.rolling(MSFT['Adj Close'],ma)
    GOOGL[column_name] = pd.DataFrame.rolling(GOOGL['Adj Close'],ma)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-20-e8debd71430e> in <module>
#       6     column_name = "MA for %s days" %(str(ma))
#       7
# ----> 8     AAPL[column_name] = pd.DataFrame.rolling(AAPL['Adj Close'],ma)
#       9     AMZN[column_name] = pd.DataFrame.rolling(AMZN['Adj Close'],ma)
#      10     MSFT[column_name] = pd.DataFrame.rolling(MSFT['Adj Close'],ma)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
# ...

# %%
# Plotting the moving averages

AAPL[['Adj Close', 'MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4), title='Apple')
AMZN[['Adj Close', 'MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4), title='Amazon')
MSFT[['Adj Close', 'MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4), title='Microsoft')
GOOGL[['Adj Close', 'MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4), title='Google')

# %%
# Plotting Daily returns as a function of Percent change in Adjusted Close value

AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()
AAPL['Daily Return'].plot(legend=True,title='Apple')

# %%
AMZN['Daily Return'] = AMZN['Adj Close'].pct_change()
AMZN['Daily Return'].plot(legend=True,title='Amazon')

# %%
MSFT['Daily Return'] = MSFT['Adj Close'].pct_change()
MSFT['Daily Return'].plot(legend=True,title='Microsoft')

# %%
GOOGL['Daily Return'] = GOOGL['Adj Close'].pct_change()
GOOGL['Daily Return'].plot(legend=True,title='Google')

# %%
# Plotting the average daily returns of the stock

sns.distplot(AAPL['Daily Return'].dropna(),bins=100).set_title('Apple')
# Out:
# Text(0.5, 1.0, 'Apple')

# %%
sns.distplot(AMZN['Daily Return'].dropna(),bins=100).set_title('Amazon')
# Out:
# Text(0.5, 1.0, 'Amazon')

# %%
sns.distplot(MSFT['Daily Return'].dropna(),bins=100).set_title('Microsoft')
# Out:
# Text(0.5, 1.0, 'Microsoft')

# %%
sns.distplot(GOOGL['Daily Return'].dropna(),bins=100).set_title('Google')
# Out:
# Text(0.5, 1.0, 'Google')

# %%
# Risk Analysis --  Comparing the Risk vs Expected returns

rets = AAPL['Daily Return'].dropna()

area = np.pi*15

plt.scatter(rets.mean(),rets.std(),s=area)
plt.title('Risk Analysis for Apple')
plt.xlabel('Expected Returns')
plt.ylabel('Risk')
# Out:
# Text(0, 0.5, 'Risk')

# %%
rets = AMZN['Daily Return'].dropna()

area = np.pi*15

plt.scatter(rets.mean(),rets.std(),s=area)
plt.title('Risk Analysis for Amazon')
plt.xlabel('Expected Returns')
plt.ylabel('Risk')
# Out:
# Text(0, 0.5, 'Risk')

# %%
rets = MSFT['Daily Return'].dropna()

area = np.pi*15

plt.scatter(rets.mean(),rets.std(),s=area)
plt.title('Risk Analysis for Microsoft')
plt.xlabel('Expected Returns')
plt.ylabel('Risk')
# Out:
# Text(0, 0.5, 'Risk')

# %%
rets = GOOGL['Daily Return'].dropna()

area = np.pi*15

plt.scatter(rets.mean(),rets.std(),s=area)
plt.title('Risk Analysis for Google')
plt.xlabel('Expected Returns')
plt.ylabel('Risk')
# Out:
# Text(0, 0.5, 'Risk')

# %%
# Visualizing the Value at Risk

sns.distplot(AAPL['Daily Return'].dropna(),bins=100).set_title('Apple')
# Out:
# Text(0.5, 1.0, 'Apple')

# %%
sns.distplot(AMZN['Daily Return'].dropna(),bins=100).set_title('Amazon')
# Out:
# Text(0.5, 1.0, 'Amazon')

# %%
sns.distplot(MSFT['Daily Return'].dropna(),bins=100).set_title('Microsoft')
# Out:
# Text(0.5, 1.0, 'Microsoft')

# %%
sns.distplot(GOOGL['Daily Return'].dropna(),bins=100).set_title('Google')
# Out:
# Text(0.5, 1.0, 'Google')

# %%
# Using Quantiles and the Bootstrap Method to calculate the numerical risk of the stock
print("Apple Numerical Risk")
AAPL['Daily Return'].quantile(0.05)
# Out:
# Apple Numerical Risk
# -0.033102823024433924

# %%
print("Amazon Numerical Risk")
AMZN['Daily Return'].quantile(0.05)
# Out:
# Amazon Numerical Risk
# -0.029935495803068052

# %%
print("Micrsoft Numerical Risk")
MSFT['Daily Return'].quantile(0.05)
# Out:
# Micrsoft Numerical Risk
# -0.027447706902481266

# %%
print("Google Numerical Risk")
GOOGL['Daily Return'].quantile(0.05)
# Out:
# Google Numerical Risk
# -0.029419294081457395

# %%
## Monte Carlo Simulation

days = 365

dt = 1/days

mu = rets.mean()

sigma = rets.std()

# %%
# Defining the Monte Carlo Simulation Function

def stock_monte_carlo(start_price,days,mu,sigma):
    
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1,days):
        shock[x] = np.random.normal(loc=mu*dt,scale=sigma*np.sqrt(dt))
        
        drift[x] = mu * dt
        
        price[x] = price[x-1] + (price[x-1]* (drift[x] + shock[x]))
        
    return price

# %%
AAPL.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-06-16  88.300003  86.180000  87.864998  88.019997  165428800.0
# 2020-06-17  88.849998  87.772499  88.787498  87.897499  114406400.0
# 2020-06-18  88.362503  87.305000  87.852501  87.932503   96820400.0
# 2020-06-19  89.139999  86.287498  88.660004  87.430000  264476000.0
# 2020-06-22  89.864998  87.787498  87.834999  89.717499  135445200.0
#
#             Adj Close  Daily Return
# Date
# 2020-06-16  87.430885           NaN
# 2020-06-17  87.309204     -0.001392
# 2020-06-18  87.343979      0.000398
# 2020-06-19  86.844833     -0.005715
# 2020-06-22  89.117027      0.026164

# %%
# Running the Monte Carlo simulation a hundred times for apple

start_price = 74.315002

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Simulation for Apple')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Simulation for Apple')

# %%
# Analysing the Monte Carlo Simulation for 10,000 simulations

runs = 10000

simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1]
    
# 1 percent impirical quantile or 99% Confidence Interval

q = np.percentile(simulations,1)

# %%
# Plotting the final Risk Analysis plot using Monte Carlo Simulation

plt.hist(simulations,bins=200)

plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Apple Stock after %s days" % days, weight='bold');

# %%
AMZN.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-06-16  2620.000000  2576.000000  2620.000000  2615.270020  3585600
# 2020-06-17  2655.000000  2631.820068  2647.500000  2640.979980  2959300
# 2020-06-18  2659.639893  2636.110107  2647.010010  2653.979980  2487800
# 2020-06-19  2697.429932  2659.000000  2678.080078  2675.010010  5777000
# 2020-06-22  2715.000000  2669.000000  2684.500000  2713.820068  3208800
#
#               Adj Close  Daily Return
# Date
# 2020-06-16  2615.270020           NaN
# 2020-06-17  2640.979980      0.009831
# 2020-06-18  2653.979980      0.004922
# 2020-06-19  2675.010010      0.007924
# 2020-06-22  2713.820068      0.014508

# %%
# Running the Monte Carlo simulation a hundred times for Amazon
start_price = 2003.180054

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Simulation for Amazon')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Simulation for Amazon')

# %%
# Analysing the Monte Carlo Simulation for 10,000 simulations

runs = 10000

simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1]
    
# 1 percent impirical quantile or 99% Confidence Interval

q = np.percentile(simulations,1)

# %%
# Plotting the final Risk Analysis plot using Monte Carlo Simulation

plt.hist(simulations,bins=200)

plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Amazon Stock after %s days" % days, weight='bold');

# %%
MSFT.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-06-16  195.580002  191.460007  192.889999  193.570007  42556700.0
# 2020-06-17  196.320007  193.690002  195.029999  194.240005  25687800.0
# 2020-06-18  196.490005  194.000000  194.000000  196.320007  23061600.0
# 2020-06-19  199.289993  194.369995  198.589996  195.149994  44441100.0
# 2020-06-22  200.759995  195.229996  195.789993  200.570007  32818900.0
#
#              Adj Close  Daily Return
# Date
# 2020-06-16  191.713745           NaN
# 2020-06-17  192.377289      0.003461
# 2020-06-18  194.437363      0.010709
# 2020-06-19  193.278564     -0.005960
# 2020-06-22  198.646606      0.027774

# %%
# Running the Monte Carlo simulation a hundred times for Microsoft
start_price = 167.770004

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Simulation for Microsoft')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Simulation for Microsoft')

# %%
# Analysing the Monte Carlo Simulation for 10,000 simulations

runs = 10000

simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1]
    
# 1 percent impirical quantile or 99% Confidence Interval

q = np.percentile(simulations,1)

# %%
# Plotting the final Risk Analysis plot using Monte Carlo Simulation

plt.hist(simulations,bins=200)

plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Microsoft Stock after %s days" % days, weight='bold');

# %%
GOOGL.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-06-16  1457.170044  1428.989990  1449.000000  1446.469971  1532400
# 2020-06-17  1462.199951  1435.130005  1452.939941  1452.540039  1530500
# 2020-06-18  1452.969971  1426.239990  1449.849976  1434.119995  1743100
# 2020-06-19  1444.500000  1419.000000  1440.000000  1424.640015  2639200
# 2020-06-22  1450.949951  1419.189941  1425.010010  1450.660034  1472100
#
#               Adj Close  Daily Return
# Date
# 2020-06-16  1446.469971           NaN
# 2020-06-17  1452.540039      0.004196
# 2020-06-18  1434.119995     -0.012681
# 2020-06-19  1424.640015     -0.006610
# 2020-06-22  1450.660034      0.018264

# %%
# Running the Monte Carlo simulation a hundred times for Google
start_price = 1423.050049

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Simulation for Google')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Simulation for Google')

# %%
# Analysing the Monte Carlo Simulation for 10,000 simulations

runs = 10000

simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1]
    
# 1 percent impirical quantile or 99% Confidence Interval

q = np.percentile(simulations,1)

# %%
# Plotting the final Risk Analysis plot using Monte Carlo Simulation

plt.hist(simulations,bins=200)

plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Google Stock after %s days" % days, weight='bold');
